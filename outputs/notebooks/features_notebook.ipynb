# %% [markdown]
# # Feature Engineering
#
# *Auto-generated by Feature Engineer Agent*

# %% [markdown]
# ## Features Created
#
# Total: 6 features

# %% [markdown]
# ### Feature List
#
# - Title
# - FamilySize
# - IsAlone
# - AgeBin
# - FarePerPerson
# - Deck

# %% [markdown]
# ## Feature Importance
#
# Top 10 features by importance:

# %% [markdown]
# 1. **Sex**: 0.1992
# 2. **Title**: 0.0970
# 3. **Ticket**: 0.0935
# 4. **Fare**: 0.0831
# 5. **Name**: 0.0776
# 6. **FarePerPerson**: 0.0751
# 7. **Age**: 0.0707
# 8. **PassengerId**: 0.0696
# 9. **Pclass**: 0.0467
# 10. **Cabin**: 0.0445
